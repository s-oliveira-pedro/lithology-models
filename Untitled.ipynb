# %%
import warnings
warnings.filterwarnings('ignore')

import os
import numpy as np
import xarray as xr
import dask

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline


import holoviews as hv
hv.notebook_extension('matplotlib')

from landlab import RasterModelGrid
from landlab.components import FlowAccumulator, FastscapeEroder, LinearDiffuser, Lithology, LithoLayers
from landlab.plot import imshow_grid
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1010'>
#   <div id="eea72e5a-6ca1-45ae-b38c-68d404d47178" data-root-id="p1010" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"6cd36beb-5eb8-4140-a71c-7e614b787090":{"version":"3.4.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1010"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1011","attributes":{"plot_id":"p1010","comm_id":"e6e0a7f82fa649af99957012c7138fed","client_comm_id":"b94f6ca6c1ab4502b2d920a37ad7de5c"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"6cd36beb-5eb8-4140-a71c-7e614b787090","roots":{"p1010":"eea72e5a-6ca1-45ae-b38c-68d404d47178"},"root_ids":["p1010"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 18
#      15 import holoviews as hv
#      16 hv.notebook_extension('matplotlib')
# ---> 18 from landlab import RasterModelGrid
#      19 from landlab.components import FlowAccumulator, FastscapeEroder, LinearDiffuser, Lithology, LithoLayers
#      20 from landlab.plot import imshow_grid
#
# File ~/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/__init__.py:20
#      18 from landlab.core.utils import ExampleData
#      19 from landlab.field.errors import FieldError
# ---> 20 from landlab.grid.base import ModelGrid
#      21 from landlab.grid.create import create_grid
#      22 from landlab.grid.framed_voronoi import FramedVoronoiGrid
#
# File ~/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/grid/__init__.py:1
# ----> 1 from landlab.grid.base import ModelGrid
#       2 from landlab.grid.create import create_grid
#       3 from landlab.grid.framed_voronoi import FramedVoronoiGrid
#
# File ~/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/grid/base.py:16
#      13 import numpy as np
#      14 import xarray as xr
# ---> 16 from landlab.utils.decorators import make_return_array_immutable
#      18 from ..core import load_params
#      19 from ..core.utils import add_module_functions_to_class
#
# File ~/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/utils/__init__.py:5
#       3 from .add_halo import add_halo
#       4 from .count_repeats import count_repeated_values
# ----> 5 from .matrix import get_core_node_at_node
#       6 from .matrix import get_core_node_matrix
#       7 from .return_array import return_array_at_link
#
# File ~/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/utils/matrix.py:7
#       4 import numpy as np
#       5 from scipy.sparse import csc_matrix
# ----> 7 from ._matrix import fill_right_hand_side
#       8 from ._matrix import get_matrix_diagonal_elements
#       9 from ._matrix import get_matrix_diagonal_elements_with_coef
#
# File ~/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/utils/_matrix.pyx:1, in init landlab.utils._matrix()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
mg = RasterModelGrid((10, 15))
z = mg.add_zeros('topographic__elevation', at='node')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mg = RasterModelGrid((10, 15))
#       2 z = mg.add_zeros('topographic__elevation', at='node')
#
# NameError: name 'RasterModelGrid' is not defined

# %%
layer_elevations = 5. * np.arange(-10, 10)

# we create a bottom layer that is very thick.
layer_elevations[-1] = layer_elevations[-2] + 100

# %%
layer_ids = np.tile([0, 1, 2, 3], 5)

# %%
attrs = {'K_sp': {0: 0.0003, 1: 0.0001, 2: 0.0002, 3: 0.0004}}

# %%
func = lambda x, y: x + (2. * y)

# %%
lith = LithoLayers(mg, layer_elevations, layer_ids, function=func, attrs=attrs)

# %%
imshow_grid(mg, 'rock_type__id', cmap='viridis')

# %%
pip install --upgrade numpy matplotlib holoviews landlab xarray dask
# Out:
# Requirement already satisfied: numpy in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (1.26.4)
# Collecting numpy
#   Downloading numpy-2.0.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 285.6 kB/s eta 0:00:00 0:00:01
# Requirement already satisfied: matplotlib in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (3.8.4)
# Collecting matplotlib
#   Downloading matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: holoviews in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (1.17.1)
# Collecting holoviews
#   Downloading holoviews-1.19.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: landlab in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: xarray in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (2023.6.0)
# Collecting xarray
#   Downloading xarray-2024.6.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: dask in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (2.10.1)
# Collecting dask
#   Using cached dask-2024.6.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib) (2.9.0)
# Collecting bokeh>=3.1 (from holoviews)
#   Downloading bokeh-3.4.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: colorcet in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from holoviews) (3.1.0)
# Requirement already satisfied: pandas>=1.3 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from holoviews) (2.2.2)
# Collecting panel>=1.0 (from holoviews)
#   Downloading panel-1.4.4-py3-none-any.whl.metadata (25 kB)
# Collecting param<3.0,>=2.0 (from holoviews)
#   Downloading param-2.1.1-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pyviz-comms>=2.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from holoviews) (3.0.2)
# Requirement already satisfied: bmipy in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2.0.1)
# Requirement already satisfied: netcdf4 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (1.7.1)
# Requirement already satisfied: pyyaml in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (6.0.1)
# Requirement already satisfied: pyshp!=2.3.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2.3.1)
# Requirement already satisfied: rich-click in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (1.8.3)
# Requirement already satisfied: scipy in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (1.14.0)
# Requirement already satisfied: statsmodels in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (0.14.2)
# Requirement already satisfied: importlib-resources in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (6.4.0)
# Requirement already satisfied: click>=8.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from dask) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from dask) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from dask) (2024.3.1)
# Requirement already satisfied: partd>=1.2.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from dask) (1.4.1)
# Requirement already satisfied: toolz>=0.10.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from dask) (0.12.0)
# Collecting importlib-metadata>=4.13.0 (from dask)
#   Downloading importlib_metadata-8.0.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: Jinja2>=2.9 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bokeh>=3.1->holoviews) (3.1.4)
# Requirement already satisfied: tornado>=6.2 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bokeh>=3.1->holoviews) (6.4.1)
# Collecting xyzservices>=2021.09.1 (from bokeh>=3.1->holoviews)
#   Downloading xyzservices-2024.6.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->dask) (3.19.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from pandas>=1.3->holoviews) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from pandas>=1.3->holoviews) (2024.1)
# Requirement already satisfied: markdown in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from panel>=1.0->holoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from panel>=1.0->holoviews) (3.0.0)
# Collecting linkify-it-py (from panel>=1.0->holoviews)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting mdit-py-plugins (from panel>=1.0->holoviews)
#   Downloading mdit_py_plugins-0.4.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: requests in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from panel>=1.0->holoviews) (2.32.2)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from panel>=1.0->holoviews) (4.66.4)
# Requirement already satisfied: bleach in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from panel>=1.0->holoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from panel>=1.0->holoviews) (4.11.0)
# Requirement already satisfied: locket in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from partd>=1.2.0->dask) (1.0.0)
# Requirement already satisfied: six>=1.5 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: black in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bmipy->landlab) (24.4.2)
# Requirement already satisfied: cftime in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from netcdf4->landlab) (1.6.4)
# Requirement already satisfied: certifi in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from netcdf4->landlab) (2024.6.2)
# Requirement already satisfied: rich>=10.7 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from rich-click->landlab) (13.7.1)
# Requirement already satisfied: patsy>=0.5.6 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from statsmodels->landlab) (0.5.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh>=3.1->holoviews) (2.1.5)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from rich>=10.7->rich-click->landlab) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from markdown-it-py->panel>=1.0->holoviews) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from black->bmipy->landlab) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from black->bmipy->landlab) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from black->bmipy->landlab) (4.2.2)
# Requirement already satisfied: webencodings in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bleach->panel>=1.0->holoviews) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->holoviews)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from requests->panel>=1.0->holoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from requests->panel>=1.0->holoviews) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from requests->panel>=1.0->holoviews) (2.2.2)
# Downloading numpy-2.0.0-cp311-cp311-macosx_11_0_arm64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 10.8 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.9.0-cp311-cp311-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading holoviews-1.19.0-py3-none-any.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 14.6 MB/s eta 0:00:00a 0:00:01
# Downloading xarray-2024.6.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 11.4 MB/s eta 0:00:00 0:00:01m
# Using cached dask-2024.6.2-py3-none-any.whl (1.2 MB)
# Downloading bokeh-3.4.2-py3-none-any.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading importlib_metadata-8.0.0-py3-none-any.whl (24 kB)
# Downloading panel-1.4.4-py3-none-any.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 19.4 MB/s eta 0:00:0000:0100:01
# Downloading param-2.1.1-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 kB 6.1 MB/s eta 0:00:00
# Downloading xyzservices-2024.6.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 966.3 kB/s eta 0:00:00:010:00:01
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading mdit_py_plugins-0.4.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 kB 4.4 MB/s eta 0:00:00
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: xyzservices, uc-micro-py, param, numpy, importlib-metadata, mdit-py-plugins, linkify-it-py, dask, xarray, matplotlib, bokeh, panel, holoviews
#   Attempting uninstall: param
#     Found existing installation: param 1.13.0
#     Uninstalling param-1.13.0:
#       Successfully uninstalled param-1.13.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: dask
#     Found existing installation: dask 2.10.1
#     Uninstalling dask-2.10.1:
#       Successfully uninstalled dask-2.10.1
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2023.6.0
#     Uninstalling xarray-2023.6.0:
#       Successfully uninstalled xarray-2023.6.0
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.3
#     Uninstalling bokeh-2.4.3:
#       Successfully uninstalled bokeh-2.4.3
#   Attempting uninstall: panel
#     Found existing installation: panel 0.14.3
#     Uninstalling panel-0.14.3:
#       Successfully uninstalled panel-0.14.3
#   Attempting uninstall: holoviews
#     Found existing installation: holoviews 1.17.1
#     Uninstalling holoviews-1.17.1:
#       Successfully uninstalled holoviews-1.17.1
# Successfully installed bokeh-3.4.2 dask-2024.6.2 holoviews-1.19.0 importlib-metadata-8.0.0 linkify-it-py-2.0.3 matplotlib-3.9.0 mdit-py-plugins-0.4.1 numpy-2.0.0 panel-1.4.4 param-2.1.1 uc-micro-py-1.0.3 xarray-2024.6.0 xyzservices-2024.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install landlab
# Out:
# Requirement already satisfied: landlab in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (2.8.0)
# Requirement already satisfied: bmipy in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2.0.1)
# Requirement already satisfied: matplotlib in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (3.9.0)
# Requirement already satisfied: netcdf4 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (1.7.1)
# Requirement already satisfied: numpy>=1.20 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2.0.0)
# Requirement already satisfied: pyyaml in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (6.0.1)
# Requirement already satisfied: pyshp!=2.3.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2.3.1)
# Requirement already satisfied: rich-click in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (1.8.3)
# Requirement already satisfied: scipy in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (1.14.0)
# Requirement already satisfied: statsmodels in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (0.14.2)
# Requirement already satisfied: pandas in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2.2.2)
# Requirement already satisfied: xarray>=0.16 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (2024.6.0)
# Requirement already satisfied: importlib-resources in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from landlab) (6.4.0)
# Requirement already satisfied: packaging>=23.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from xarray>=0.16->landlab) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from pandas->landlab) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from pandas->landlab) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from pandas->landlab) (2024.1)
# Requirement already satisfied: black in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bmipy->landlab) (24.4.2)
# Requirement already satisfied: click in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bmipy->landlab) (8.1.7)
# Requirement already satisfied: jinja2 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from bmipy->landlab) (3.1.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib->landlab) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib->landlab) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib->landlab) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib->landlab) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib->landlab) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from matplotlib->landlab) (3.1.2)
# Requirement already satisfied: cftime in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from netcdf4->landlab) (1.6.4)
# Requirement already satisfied: certifi in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from netcdf4->landlab) (2024.6.2)
# Requirement already satisfied: rich>=10.7 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from rich-click->landlab) (13.7.1)
# Requirement already satisfied: typing-extensions in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from rich-click->landlab) (4.11.0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from statsmodels->landlab) (0.5.6)
# Requirement already satisfied: six in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from patsy>=0.5.6->statsmodels->landlab) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from rich>=10.7->rich-click->landlab) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from rich>=10.7->rich-click->landlab) (2.18.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from black->bmipy->landlab) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from black->bmipy->landlab) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from black->bmipy->landlab) (4.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from jinja2->bmipy->landlab) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.7->rich-click->landlab) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip unistall landlab
# Out:
# ERROR: unknown command "unistall" - maybe you meant "uninstall"
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall landlab
# Out:
# Found existing installation: landlab 2.8.0
# Uninstalling landlab-2.8.0:
#   Would remove:
#     /Users/poliveira/anaconda3/envs/pedro_land/bin/landlab
#     /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab-2.8.0.dist-info/*
#     /Users/poliveira/anaconda3/envs/pedro_land/lib/python3.11/site-packages/landlab/*
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
jupyter labextension install @jupyter-widgets/jupyterlab-manager
jupyter labextension install @pyviz/jupyterlab_pyviz
# Out:
#   Cell In[13], line 1
#     jupyter labextension install @jupyter-widgets/jupyterlab-manager
#             ^
# SyntaxError: invalid syntax
